# %%
import pandas as pd
pd.Series([1,2],index=['one','two'])
# Out:
# one    1
# two    2
# dtype: int64

# %%
data = pd.read_csv("sample.csv")
data
# Out:
#       name  salary  year
# 0   harshi   25000  2019
# 1  saiteja   30000  2015
# 2    kiran   35000  2016
# 3   naseer   40000  2015

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
data=pd.read_csv("sample.csv",header=None)
data
# Out:
#          0       1     2
# 0     name  salary  year
# 1   harshi   25000  2019
# 2  saiteja   30000  2015
# 3    kiran   35000  2016
# 4   naseer   40000  2015

# %%
data=pd.read_csv("sample.csv",sep='\t')
data
# Out:
#      name,salary,year
# 0   harshi,25000,2019
# 1  saiteja,30000,2015
# 2    kiran,35000,2016
# 3   naseer,40000,2015

# %%
data=pd.read_csv("sample.csv",usecols=['name'])
data
# Out:
#       name
# 0   harshi
# 1  saiteja
# 2    kiran
# 3   naseer

# %%
data=pd.read_csv("sample.csv",usecols=['salary'])
data
# Out:
#    salary
# 0   25000
# 1   30000
# 2   35000
# 3   40000

# %%
data=pd.read_csv("sample.csv",usecols=['year'])
data
# Out:
#    year
# 0  2019
# 1  2015
# 2  2016
# 3  2015

# %%
first=pd.read_csv("first.csv")
first
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# ...     ...                         ...                  ...
# 27805  2013                     Level 3                 ZZ11
# 27806  2013                     Level 3                 ZZ11
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
first.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
first['Year']
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 27805    2013
# 27806    2013
# 27807    2013
# 27808    2013
# 27809    2013
# Name: Year, Length: 27810, dtype: int64

# %%
first.Year
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 27805    2013
# 27806    2013
# 27807    2013
# 27808    2013
# 27809    2013
# Name: Year, Length: 27810, dtype: int64

# %%
print(type(first['Year']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(first[['Year']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
first[['Value','Units']]
# Out:
#         Value               Units
# 0      691859  Dollars (millions)
# 1      605766  Dollars (millions)
# 2       63509  Dollars (millions)
# 3       22583  Dollars (millions)
# 4      597623  Dollars (millions)
# ...       ...                 ...
# 27805      52          Percentage
# 27806      40          Percentage
# 27807      12          Percentage
# 27808       5          Percentage
# 27809      46          Percentage
#
# [27810 rows x 2 columns]

# %%
print(first.shape)
print(first.shape[0]) # no of rows
print(first.shape[1]) # no of cols
# Out:
# (27810, 10)
# 27810
# 10

# %%
first.head() # default value is 5
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2018                     Level 1                99999       All industries
# 1  2018                     Level 1                99999       All industries
# 2  2018                     Level 1                99999       All industries
# 3  2018                     Level 1                99999       All industries
# 4  2018                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
first.head(3)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2018                     Level 1                99999       All industries
# 1  2018                     Level 1                99999       All industries
# 2  2018                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
#
#     Value                             Industry_code_ANZSIC06
# 0  691859  ANZSIC06 divisions A-S (excluding classes K633...
# 1  605766  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %%
first.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27805  2013                     Level 3                 ZZ11
# 27806  2013                     Level 3                 ZZ11
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 27805  Food product manufacturing  Percentage           H37
# 27806  Food product manufacturing  Percentage           H38
# 27807  Food product manufacturing  Percentage           H39
# 27808  Food product manufacturing  Percentage           H40
# 27809  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 27805                          Quick ratio  Financial ratios    52
# 27806  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
first.tail(3)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 27807  Food product manufacturing  Percentage           H39
# 27808  Food product manufacturing  Percentage           H40
# 27809  Food product manufacturing  Percentage           H41
#
#                 Variable_name Variable_category Value  \
# 27807        Return on equity  Financial ratios    12
# 27808  Return on total assets  Financial ratios     5
# 27809   Liabilities structure  Financial ratios    46
#
#                                   Industry_code_ANZSIC06
# 27807  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 27808  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 27809  ANZSIC06 groups C111, C112, C113, C114, C115, ...

# %%
first.sample()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 17440  2015                     Level 4                LL122
#
#                      Industry_name_NZSIOC               Units Variable_code  \
# 17440  Non-Residential Property Operation  Dollars (millions)           H25
#
#         Variable_name   Variable_category  Value  Industry_code_ANZSIC06
# 17440  Current assets  Financial position  21036  ANZSIC06 class L671200

# %%
first.sample(6) # display random rows
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 6403   2017                     Level 3                 DD12
# 21549  2014                     Level 1                   JJ
# 1423   2018                     Level 3                 CC81
# 2300   2018                     Level 1                   GH
# 22509  2014                     Level 1                   OO
# 15857  2015                     Level 4                EE121
#
#                                Industry_name_NZSIOC               Units  \
# 6403   Water, Sewerage, Drainage and Waste Services             Dollars
# 21549      Information Media and Telecommunications  Dollars (millions)
# 1423              Transport Equipment Manufacturing          Percentage
# 2300                 Retail Trade and Accommodation  Dollars (millions)
# 22509  Public Order, Safety and Regulatory Services  Dollars (millions)
# 15857      Heavy and Civil Engineering Construction  Dollars (millions)
#
# ...

# %%
data=pd.read_csv("sample.csv")
data
# Out:
#       name   salary  year
# 0   harshi  25000.0  2019
# 1  saiteja  30000.0  2015
# 2    kiran      NaN  2016
# 3   naseer  40000.0  2015

# %%
first.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
first.Year.dtype
# Out:
# dtype('int64')

# %%
first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27810 entries, 0 to 27809
# Data columns (total 10 columns):
# Year                           27810 non-null int64
# Industry_aggregation_NZSIOC    27810 non-null object
# Industry_code_NZSIOC           27810 non-null object
# Industry_name_NZSIOC           27810 non-null object
# Units                          27810 non-null object
# Variable_code                  27810 non-null object
# Variable_name                  27810 non-null object
# Variable_category              27810 non-null object
# Value                          27810 non-null object
# Industry_code_ANZSIC06         27810 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# name      4 non-null object
# salary    3 non-null float64
# year      4 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
first.dtypes.value_counts()
# Out:
# object    9
# int64     1
# dtype: int64

# %%
first.dtypes.value_counts()[0]
# Out:
# 9

# %%
type(first.dtypes.value_counts().index[0])
# Out:
# numpy.dtype

# %%
first.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
import numpy as np
first.dtypes==np.int64
# Out:
# Year                            True
# Industry_aggregation_NZSIOC    False
# Industry_code_NZSIOC           False
# Industry_name_NZSIOC           False
# Units                          False
# Variable_code                  False
# Variable_name                  False
# Variable_category              False
# Value                          False
# Industry_code_ANZSIC06         False
# dtype: bool

# %%
first.columns[first.dtypes==np.int64]
# Out:
# Index(['Year'], dtype='object')
