# %% [markdown]
# [my site](https://sites.google.com/view/sairaj-python/home)

# %% [markdown]
# ***hi***

# %% [markdown]
# * to the beautiful **hi priya**

# %% [markdown]
#  * absolute *gorgeous* priya

# %% [markdown]
#   [logo](https://www.google.com/imgres?imgurl=https%3A%2F%2Fupload.wikimedia.org%2Fwikipedia%2Fcommons%2Fthumb%2Fc%2Fc3%2FPython-logo-notext.svg%2F1024px-Python-logo-notext.svg.png&imgrefurl=https%3A%2F%2Fcommons.wikimedia.org%2Fwiki%2FFile%3APython-logo-notext.svg&docid=X6b2dkbhySknGM&tbnid=pCDxQjgV-aSV0M%3A&vet=10ahUKEwiJmNmy1frlAhUFKY8KHdRqATwQMwh4KAAwAA..i&w=1024&h=1024&bih=803&biw=1707&q=python%20logo&ved=0ahUKEwiJmNmy1frlAhUFKY8KHdRqATwQMwh4KAAwAA&iact=mrc&uact=8)

# %% [markdown]
# <img arc='logo.png'/> ![image.png](attachment:image.png)

# %%
print("hello world ")
# Out:
# hello world

# %%
#circles and triangles
def sumOfCirclesTriangles(n):
    s = 0
    while n !=0:
        r = n%10
        if i==0 or i==6 or i==9:
            s = s + 2
        elif r == 8:
            s = s + 4
        elif r == 4:
            s = s + 3
        n = n // 10
    return s
x = int(input(''))

# %%
n=6547
lst = []
while n!=0:
    rem=n%10
    lst.append(rem)
    n=n//10
x=sorted(1)
print('<{},{}>'.format(x[0],x[-1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d65cce274fff> in <module>
#       5     lst.append(rem)
#       6     n=n//10
# ----> 7 x=sorted(1)
#       8 print('<{},{}>'.format(x[0],x[-1]))
#
# TypeError: 'int' object is not iterable

# %%
a=int(input("enter a number"))
r=0
while a!=0:
    rem=a%10
    r=r+rem**3
    a=a//10
r
# Out:
# enter a number122
# 17

# %%
a=int(input("enter a string"))
l=[]
l=list(a)
l
